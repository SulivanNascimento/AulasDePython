# %% [markdown]
# <a href="https://colab.research.google.com/github/SulivanNascimento/AulasDePython/blob/main/AULA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hellow Worlds")
# Out:
# Hellow Worlds

# %%
import pandas as pd

# %%
combustiveis_df = pd.read_excel("/content/ca-2021-02.xlsx")

# %%
display(combustiveis_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
ca_df = combustiveis_df[['Revenda', 'Municipio', 'Produto', 'Valor de Venda']]
display(ca_df)
# Out:
#                                            Revenda  Municipio  \
# 0                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 1                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 2                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 3                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 4                             POSTO ARAPIRACA LTDA  ARAPIRACA
# ...                                            ...        ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA     JEQUIE
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
#
#                    Produto  Valor de Venda
# 0                 GASOLINA           6.799
# 1                   ETANOL           5.299
# 2                   DIESEL           5.549
# 3       GASOLINA ADITIVADA           6.899
# ...

# %%
display(ca_df.loc[3])
# Out:
# Revenda           POSTO ARAPIRACA LTDA
# Municipio                    ARAPIRACA
# Produto             GASOLINA ADITIVADA
# Valor de Venda                   6.899
# Name: 3, dtype: object

# %%
# Qual a média de preços dos combustíveis GASOLINA e GASOLINA ADITIVADA do bairro MOOCA em SÃO PAULO?
display(combustiveis_df.loc[(combustiveis_df['Bairro'] == 'MOOCA') & (combustiveis_df['Municipio'] == 'SAO PAULO')])
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 11588              SE             SP  SAO PAULO
# 11589              SE             SP  SAO PAULO
# 11590              SE             SP  SAO PAULO
# 11591              SE             SP  SAO PAULO
# 11646              SE             SP  SAO PAULO
# ...               ...            ...        ...
# 140718             SE             SP  SAO PAULO
# 140719             SE             SP  SAO PAULO
# 140720             SE             SP  SAO PAULO
# 142000             SE             SP  SAO PAULO
# 142001             SE             SP  SAO PAULO
#
#                                     Revenda      CNPJ da Revenda  \
# 11588                   AUTO POSTO LIK LTDA   05.335.456/0001-26
# 11589                   AUTO POSTO LIK LTDA   05.335.456/0001-26
# 11590                   AUTO POSTO LIK LTDA   05.335.456/0001-26
# 11591                   AUTO POSTO LIK LTDA   05.335.456/0001-26
# ...

# %%
combustiveis_df.loc[(combustiveis_df['Bairro'] == 'MOOCA') & (combustiveis_df['Municipio'] == 'SAO PAULO')]
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 11588              SE             SP  SAO PAULO
# 11589              SE             SP  SAO PAULO
# 11590              SE             SP  SAO PAULO
# 11591              SE             SP  SAO PAULO
# 11646              SE             SP  SAO PAULO
# ...               ...            ...        ...
# 140718             SE             SP  SAO PAULO
# 140719             SE             SP  SAO PAULO
# 140720             SE             SP  SAO PAULO
# 142000             SE             SP  SAO PAULO
# 142001             SE             SP  SAO PAULO
#
#                                     Revenda      CNPJ da Revenda  \
# 11588                   AUTO POSTO LIK LTDA   05.335.456/0001-26
# 11589                   AUTO POSTO LIK LTDA   05.335.456/0001-26
# 11590                   AUTO POSTO LIK LTDA   05.335.456/0001-26
# 11591                   AUTO POSTO LIK LTDA   05.335.456/0001-26
# ...

# %%
#GASOLINA e GASOLINA ADITIVADA do Bairro MOOCA em SÃO PAULO e a média de preço
display(combustiveis_df.loc[(combustiveis_df['Bairro'] == 'MOOCA') &
    (combustiveis_df['Municipio'] == 'SAO PAULO') &
    ((combustiveis_df['Produto'] == 'GASOLINA') | (combustiveis_df['Produto'] == 'GASOLINA ADITIVADA')),
    ['Valor de Venda']].mean())
# Out:
# Valor de Venda    6.575596
# dtype: float64
